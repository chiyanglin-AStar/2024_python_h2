# %% [markdown]
# <a href="https://colab.research.google.com/github/chiyanglin-AStar/2024_python_h2/blob/main/colab_ex2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Colab is from Jupyter notebook
#
# ## Colab is from Jupyter notebook
#
# ### Colab is from Jupyter notebook

# %% [markdown]
# Colab is from Jupyter notebook

# %%
print("hello world")
# Out:
# hello world

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()
